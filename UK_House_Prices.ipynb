# %% [markdown]
# <a href="https://colab.research.google.com/github/jimbojamborine/Projects/blob/main/UK_House_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import timedelta
import plotly.express as px

#Link to Gov HPI data
url = 'http://publicdata.landregistry.gov.uk/market-trend-data/house-price-index-data/UK-HPI-full-file-2022-03.csv'

df = pd.read_csv(url)

#Turn to datetime
df['datetime'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

#get date values and sort for querying
dates = df['datetime'].unique()
date_df = pd.DataFrame(dates,columns=['dates'])

date_df = date_df.sort_values('dates',ascending=False)

d_1 = date_df['dates'].iloc[36]
d_2 = date_df['dates'].iloc[0]

#set date values
pre_df = df[df['datetime'] == d_1]
now_df = df[df['datetime']== d_2]

#set dataframes to compare
pre_df = pre_df[
                ['datetime',
                 'RegionName',
                 'AreaCode',
                 'Index',
                 'AveragePrice'
                 ]
                ]
now_df = now_df[
                ['RegionName',
                 'Index',
                 'AveragePrice'
                 ]
                ]

#join to master df
df_j = pre_df.merge(now_df, on='RegionName',how='left')

#calculate change between two dfs
df_j['HPI Change'] = (df_j['Index_y'] - df_j['Index_x']) / df_j['Index_x'] * 100
df_j['Avg Price Change'] = (df_j['AveragePrice_y'] - df_j['AveragePrice_x'])

change_df = df_j[
                 ['RegionName', 
                  'AreaCode', 
                  'HPI Change',
                  'Avg Price Change',
                  'AveragePrice_y'
                  ]
                 ]

change_df['country'] = change_df['AreaCode'].str[0]

#remove aggregate country
change_df = change_df.loc[change_df["country"] !='K']

#rename countries
change_df['country'].replace('S','Scotland',inplace=True)
change_df['country'].replace('W','Wales',inplace=True)
change_df['country'].replace('N','Northern Ireland',inplace=True)
change_df['country'].replace('E','England',inplace=True)

#create list of countries for loop
countries = change_df['country'].unique()

for country in countries:
  temp = change_df[change_df['country']==country]

  #visualistion
  fig = px.scatter(temp, 
                   x='Avg Price Change', 
                   y='HPI Change', 
                   title= country + ' Average House Price Change vs HPI Change By Region - ' + d_2.strftime('%Y/%m') + " vs " + d_1.strftime('%Y/%m'), 
                   color='RegionName', 
                   size='AveragePrice_y', 
                   hover_data=['RegionName','HPI Change','Avg Price Change']
                   )
  fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4b72098c-a3a2-4e0e-9b5c-b4f65f5417c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b72098c-a3a2-4e0e-9b5c-b4f65f5417c1")) {                    Plotly.newPlot(                        "4b72098c-a3a2-4e0e-9b5c-b4f65f5417c1",                        [{"customdata":[["Aberdeenshire"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Aberdeenshire","marker":{"color":"#636efa","size":[199789.1573],"sizemode":"area","sizeref":807.13761075,"symbol":"circle"},"mode":"markers","name":"Aberdeenshire","orientation":"v","showlegend":true,"x":[19330.744600000005],"xaxis":"x","y":[10.712021885368612],"yaxis":"y","type":"scatter"},{"customdata":[["Angus"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Angus","marker":{"color":"#EF553B","size":[160906.3139],"sizemode":"area","sizeref":807.13761075,"symbol":"circle"},"mode":"markers","name":"Angus","orientation":"v","showlegend":true,"x":[17462.88870000001],"xaxis":"x","y":[12.1740599901061],"yaxis":"y","type":"scatter"},{"customdata":[["Argyll and Bute"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Argyll and Bute","marker":{"color":"#00cc96","size":[183706.8888],"sizemode":"area","sizeref":807.13761075,"symbol":"circle"},"mode":"markers","name":"Argyll and Bute","orientation":"v","showlegend":true,"x":[41526.561799999996],"xaxis":"x","y":[29.206967340777613],"yaxis":"y","type":"scatter"},{"customdata":[["City of Aberdeen"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"City of Aberdeen","marker":{"color":"#ab63fa","size":[142803.6448],"sizemode":"area","sizeref":807.13761075,"symbol":"circle"},"mode":"markers","name":"City of Aberdeen","orientation":"v","showlegend":true,"x":[-7044.084899999987],"xaxis":"x","y":[-4.700828536741687],"yaxis":"y","type":"scatter"},{"customdata":[["City of Dundee"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"City of Dundee","marker":{"color":"#FFA15A","size":[142690.1231],"sizemode":"area","sizeref":807.13761075,"symbol":"circle"},"mode":"markers","name":"City of Dundee","orientation":"v","showlegend":true,"x":[24783.11099999999],"xaxis":"x","y":[21.019200195325524],"yaxis":"y","type":"scatter"},{"customdata":[["City of Edinburgh"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"City of Edinburgh","marker":{"color":"#19d3f3","size":[322855.0443],"sizemode":"area","sizeref":807.13761075,"symbol":"circle"},"mode":"markers","name":"City of Edinburgh","orientation":"v","showlegend":true,"x":[60749.72020000001],"xaxis":"x","y":[23.177598740101992],"yaxis":"y","type":"scatter"},{"customdata":[["City of Glasgow"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"City of Glasgow","marker":{"color":"#FF6692","size":[164252.6305],"sizemode":"area","sizeref":807.13761075,"symbol":"circle"},"mode":"markers","name":"City of Glasgow","orientation":"v","showlegend":true,"x":[33795.02589999999],"xaxis":"x","y":[25.904987281937036],"yaxis":"y","type":"scatter"},{"customdata":[["Clackmannanshire"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7ef69f26-722b-4203-87ce-94a686f7ff06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ef69f26-722b-4203-87ce-94a686f7ff06")) {                    Plotly.newPlot(                        "7ef69f26-722b-4203-87ce-94a686f7ff06",                        [{"customdata":[["Adur"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Adur","marker":{"color":"#636efa","size":[367219.9489],"sizemode":"area","sizeref":3628.9175825,"symbol":"circle"},"mode":"markers","name":"Adur","orientation":"v","showlegend":true,"x":[60597.2463],"xaxis":"x","y":[19.762804847616106],"yaxis":"y","type":"scatter"},{"customdata":[["Allerdale"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Allerdale","marker":{"color":"#EF553B","size":[188008.8706],"sizemode":"area","sizeref":3628.9175825,"symbol":"circle"},"mode":"markers","name":"Allerdale","orientation":"v","showlegend":true,"x":[38066.94029999999],"xaxis":"x","y":[25.38778861278968],"yaxis":"y","type":"scatter"},{"customdata":[["Amber Valley"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Amber Valley","marker":{"color":"#00cc96","size":[223367.9485],"sizemode":"area","sizeref":3628.9175825,"symbol":"circle"},"mode":"markers","name":"Amber Valley","orientation":"v","showlegend":true,"x":[51271.147800000006],"xaxis":"x","y":[29.792040033041534],"yaxis":"y","type":"scatter"},{"customdata":[["Arun"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Arun","marker":{"color":"#ab63fa","size":[354693.5575],"sizemode":"area","sizeref":3628.9175825,"symbol":"circle"},"mode":"markers","name":"Arun","orientation":"v","showlegend":true,"x":[74453.07549999998],"xaxis":"x","y":[26.567566150287185],"yaxis":"y","type":"scatter"},{"customdata":[["Ashfield"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Ashfield","marker":{"color":"#FFA15A","size":[185363.6294],"sizemode":"area","sizeref":3628.9175825,"symbol":"circle"},"mode":"markers","name":"Ashfield","orientation":"v","showlegend":true,"x":[45976.65210000001],"xaxis":"x","y":[32.984897803309934],"yaxis":"y","type":"scatter"},{"customdata":[["Ashford"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Ashford","marker":{"color":"#19d3f3","size":[356146.3661],"sizemode":"area","sizeref":3628.9175825,"symbol":"circle"},"mode":"markers","name":"Ashford","orientation":"v","showlegend":true,"x":[61239.45999999996],"xaxis":"x","y":[20.765692069405333],"yaxis":"y","type":"scatter"},{"customdata":[["Babergh"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Babergh","marker":{"color":"#FF6692","size":[351243.0943],"sizemode":"area","sizeref":3628.9175825,"symbol":"circle"},"mode":"markers","name":"Babergh","orientation":"v","showlegend":true,"x":[62608.2034],"xaxis":"x","y":[21.691141752772666],"yaxis":"y","type":"scatter"},{"customdata":[["Barking and Dagenham"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Barking and Dagenham","marker":{"color":"#B6E88 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0e3bf30b-ea10-4438-bd93-1671779bd306" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e3bf30b-ea10-4438-bd93-1671779bd306")) {                    Plotly.newPlot(                        "0e3bf30b-ea10-4438-bd93-1671779bd306",                        [{"customdata":[["Antrim and Newtownabbey"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Antrim and Newtownabbey","marker":{"color":"#636efa","size":[166678.1599],"sizemode":"area","sizeref":474.91997000000003,"symbol":"circle"},"mode":"markers","name":"Antrim and Newtownabbey","orientation":"v","showlegend":true,"x":[27584.21239999999],"xaxis":"x","y":[19.831353552437704],"yaxis":"y","type":"scatter"},{"customdata":[["Ards and North Down"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Ards and North Down","marker":{"color":"#EF553B","size":[187946.6437],"sizemode":"area","sizeref":474.91997000000003,"symbol":"circle"},"mode":"markers","name":"Ards and North Down","orientation":"v","showlegend":true,"x":[36752.461499999976],"xaxis":"x","y":[24.308118797443683],"yaxis":"y","type":"scatter"},{"customdata":[["Armagh City Banbridge and Craigavon"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Armagh City Banbridge and Craigavon","marker":{"color":"#00cc96","size":[146576.912],"sizemode":"area","sizeref":474.91997000000003,"symbol":"circle"},"mode":"markers","name":"Armagh City Banbridge and Craigavon","orientation":"v","showlegend":true,"x":[25756.559700000013],"xaxis":"x","y":[21.318063704833936],"yaxis":"y","type":"scatter"},{"customdata":[["Belfast"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Belfast","marker":{"color":"#ab63fa","size":[152603.0029],"sizemode":"area","sizeref":474.91997000000003,"symbol":"circle"},"mode":"markers","name":"Belfast","orientation":"v","showlegend":true,"x":[23814.637299999988],"xaxis":"x","y":[18.49129553912965],"yaxis":"y","type":"scatter"},{"customdata":[["Causeway Coast and Glens"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Causeway Coast and Glens","marker":{"color":"#FFA15A","size":[183110.3391],"sizemode":"area","sizeref":474.91997000000003,"symbol":"circle"},"mode":"markers","name":"Causeway Coast and Glens","orientation":"v","showlegend":true,"x":[39789.705200000026],"xaxis":"x","y":[27.771087471319294],"yaxis":"y","type":"scatter"},{"customdata":[["Derry City and Strabane"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Derry City and Strabane","marker":{"color":"#19d3f3","size":[145740.7756],"sizemode":"area","sizeref":474.91997000000003,"symbol":"circle"},"mode":"markers","name":"Derry City and Strabane","orientation":"v","showlegend":true,"x":[24110.077399999995],"xaxis":"x","y":[19.82236197030649],"yaxis":"y","type":"scatter"},{"customdata":[["Fermanagh and Omagh"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Fermanagh and Omagh","marker":{"color":"#FF6692","size":[153267.098],"sizemode":"area","sizeref":474.91997000000003,"symbol":"circle"},"mode":"markers","name":"Fermanagh and Omagh","orientation": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="588f72c2-4c09-4f4e-98b6-98941c9118b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("588f72c2-4c09-4f4e-98b6-98941c9118b0")) {                    Plotly.newPlot(                        "588f72c2-4c09-4f4e-98b6-98941c9118b0",                        [{"customdata":[["Blaenau Gwent"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Blaenau Gwent","marker":{"color":"#636efa","size":[125622.1873],"sizemode":"area","sizeref":855.5626880000001,"symbol":"circle"},"mode":"markers","name":"Blaenau Gwent","orientation":"v","showlegend":true,"x":[32547.80678],"xaxis":"x","y":[34.96967327629946],"yaxis":"y","type":"scatter"},{"customdata":[["Bridgend"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Bridgend","marker":{"color":"#EF553B","size":[190691.1995],"sizemode":"area","sizeref":855.5626880000001,"symbol":"circle"},"mode":"markers","name":"Bridgend","orientation":"v","showlegend":true,"x":[42117.707399999985],"xaxis":"x","y":[28.348063110565906],"yaxis":"y","type":"scatter"},{"customdata":[["Caerphilly"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Caerphilly","marker":{"color":"#00cc96","size":[174261.0752],"sizemode":"area","sizeref":855.5626880000001,"symbol":"circle"},"mode":"markers","name":"Caerphilly","orientation":"v","showlegend":true,"x":[38996.97629999998],"xaxis":"x","y":[28.83024879344262],"yaxis":"y","type":"scatter"},{"customdata":[["Cardiff"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Cardiff","marker":{"color":"#ab63fa","size":[248957.6277],"sizemode":"area","sizeref":855.5626880000001,"symbol":"circle"},"mode":"markers","name":"Cardiff","orientation":"v","showlegend":true,"x":[40743.17630000002],"xaxis":"x","y":[19.56789067208878],"yaxis":"y","type":"scatter"},{"customdata":[["Carmarthenshire"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Carmarthenshire","marker":{"color":"#FFA15A","size":[200872.828],"sizemode":"area","sizeref":855.5626880000001,"symbol":"circle"},"mode":"markers","name":"Carmarthenshire","orientation":"v","showlegend":true,"x":[56531.54500000001],"xaxis":"x","y":[39.16519506653644],"yaxis":"y","type":"scatter"},{"customdata":[["Ceredigion"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Ceredigion","marker":{"color":"#19d3f3","size":[247000.8558],"sizemode":"area","sizeref":855.5626880000001,"symbol":"circle"},"mode":"markers","name":"Ceredigion","orientation":"v","showlegend":true,"x":[64599.4216],"xaxis":"x","y":[35.4160711893994],"yaxis":"y","type":"scatter"},{"customdata":[["Conwy"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra></extra>","legendgroup":"Conwy","marker":{"color":"#FF6692","size":[206285.4325],"sizemode":"area","sizeref":855.5626880000001,"symbol":"circle"},"mode":"markers","name":"Conwy","orientation":"v","showlegend":true,"x":[41333.90339999998],"xaxis":"x","y":[25.058211634566952],"yaxis":"y","type":"scatter"},{"customdata":[["Denbighshire"]],"hovertemplate":"RegionName=%{customdata[0]}<br>Avg Price Change=%{x}<br>HPI Change=%{y}<br>AveragePrice_y=%{marker.size}<extra ...
